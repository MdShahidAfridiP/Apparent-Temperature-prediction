# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
dataset=pd.read_csv("weatherHistory.csv")
dataset.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# ...

# %%
dataset.shape
# Out:
# (96453, 12)

# %%
dataset.drop('Formatted Date',axis=1,inplace=True)

# %%
dataset["Precip Type"].value_counts()
# Out:
# rain    85224
# snow    10712
# Name: Precip Type, dtype: int64

# %%
summarys=dataset['Summary'].value_counts()

# %%
summarys=dict(summarys)

# %%
dataset['Summary'].value_counts()
# Out:
# Partly Cloudy                          31733
# Mostly Cloudy                          28094
# Overcast                               16597
# Clear                                  10890
# Foggy                                   7148
# Breezy and Overcast                      528
# Breezy and Mostly Cloudy                 516
# Breezy and Partly Cloudy                 386
# Dry and Partly Cloudy                     86
# Windy and Partly Cloudy                   67
# Light Rain                                63
# Breezy                                    54
# Windy and Overcast                        45
# Humid and Mostly Cloudy                   40
# Drizzle                                   39
# Windy and Mostly Cloudy                   35
# Breezy and Foggy                          35
# Dry                                       34
# Humid and Partly Cloudy                   17
# Dry and Mostly Cloudy                     14
# Rain                                      10
# ...

# %%
dataset.head()
# Out:
#          Summary Precip Type  Temperature (C)  Apparent Temperature (C)  \
# 0  Partly Cloudy        rain         9.472222                  7.388889
# 1  Partly Cloudy        rain         9.355556                  7.227778
# 2  Mostly Cloudy        rain         9.377778                  9.377778
# 3  Partly Cloudy        rain         8.288889                  5.944444
# 4  Mostly Cloudy        rain         8.755556                  6.977778
#
#    Humidity  Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  \
# 0      0.89            14.1197                   251.0          15.8263
# 1      0.86            14.2646                   259.0          15.8263
# 2      0.89             3.9284                   204.0          14.9569
# 3      0.83            14.1036                   269.0          15.8263
# 4      0.83            11.0446                   259.0          15.8263
#
#    Loud Cover  Pressure (millibars)                      Daily Summary
# ...

# %%
dataset['Summary']=dataset["Summary"].map(summarys)

# %%
dataset.head()
# Out:
#    Summary Precip Type  Temperature (C)  Apparent Temperature (C)  Humidity  \
# 0    31733        rain         9.472222                  7.388889      0.89
# 1    31733        rain         9.355556                  7.227778      0.86
# 2    28094        rain         9.377778                  9.377778      0.89
# 3    31733        rain         8.288889                  5.944444      0.83
# 4    28094        rain         8.755556                  6.977778      0.83
#
#    Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# 0            14.1197                   251.0          15.8263         0.0
# 1            14.2646                   259.0          15.8263         0.0
# 2             3.9284                   204.0          14.9569         0.0
# 3            14.1036                   269.0          15.8263         0.0
# 4            11.0446                   259.0          15.8263         0.0
#
#    Pressure (millibars)                      Daily Summary
# ...

# %%
dataset['Daily Summary'].value_counts()
# Out:
# Mostly cloudy throughout the day.                                                                                              20085
# Partly cloudy throughout the day.                                                                                               9981
# Partly cloudy until night.                                                                                                      6169
# Partly cloudy starting in the morning.                                                                                          5184
# Foggy in the morning.                                                                                                           4201
#                                                                                                                                ...
# Partly cloudy starting in the morning continuing until night and breezy starting in the afternoon continuing until evening.       24
# ...

# %%
summarys=dataset['Daily Summary'].value_counts()

# %%
dataset['Daily Summary']=dataset["Daily Summary"].map(summarys)

# %%
dataset.head()
# Out:
#    Summary Precip Type  Temperature (C)  Apparent Temperature (C)  Humidity  \
# 0    31733        rain         9.472222                  7.388889      0.89
# 1    31733        rain         9.355556                  7.227778      0.86
# 2    28094        rain         9.377778                  9.377778      0.89
# 3    31733        rain         8.288889                  5.944444      0.83
# 4    28094        rain         8.755556                  6.977778      0.83
#
#    Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# 0            14.1197                   251.0          15.8263         0.0
# 1            14.2646                   259.0          15.8263         0.0
# 2             3.9284                   204.0          14.9569         0.0
# 3            14.1036                   269.0          15.8263         0.0
# 4            11.0446                   259.0          15.8263         0.0
#
#    Pressure (millibars)  Daily Summary
# ...

# %%
df=pd.get_dummies(dataset,drop_first=True)
df.head()
# Out:
#    Summary  Temperature (C)  Apparent Temperature (C)  Humidity  \
# 0    31733         9.472222                  7.388889      0.89
# 1    31733         9.355556                  7.227778      0.86
# 2    28094         9.377778                  9.377778      0.89
# 3    31733         8.288889                  5.944444      0.83
# 4    28094         8.755556                  6.977778      0.83
#
#    Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# 0            14.1197                   251.0          15.8263         0.0
# 1            14.2646                   259.0          15.8263         0.0
# 2             3.9284                   204.0          14.9569         0.0
# 3            14.1036                   269.0          15.8263         0.0
# 4            11.0446                   259.0          15.8263         0.0
#
#    Pressure (millibars)  Daily Summary  Precip Type_snow
# 0               1015.13           9981                 0
# ...

# %%
df['Precip Type_snow'].value_counts()
# Out:
# 0    85741
# 1    10712
# Name: Precip Type_snow, dtype: int64

# %%
import matplotlib.pyplot as plt
for i in df.columns:
    plt.title(i)
    df[i].hist()
    plt.show()

# %%
df.isnull().sum()
# Out:
# Summary                     0
# Temperature (C)             0
# Apparent Temperature (C)    0
# Humidity                    0
# Wind Speed (km/h)           0
# Wind Bearing (degrees)      0
# Visibility (km)             0
# Loud Cover                  0
# Pressure (millibars)        0
# Daily Summary               0
# Precip Type_snow            0
# dtype: int64

# %%
plt.figure(figsize=(12,9))
sns.heatmap(df.corr(),annot=True,cmap='viridis')

# %%
df.drop("Loud Cover",axis=1,inplace=True)

# %%
plt.figure(figsize=(12,9))
sns.heatmap(df.corr(),annot=True,cmap='viridis')

# %%
x=df.drop("Apparent Temperature (C)",axis=1)
y=df['Apparent Temperature (C)']

# x['Humidity']=np.log(x['Humidity']+1)
# x['Visibility (km)']=np.log(x['Visibility (km)']+1)
# x['Wind Bearing (degrees)']=np.log(x['Wind Bearing (degrees)']+1)

# from sklearn.preprocessing import StandardScaler
# x=StandardScaler().fit_transform(x)

from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=0)

from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(xtrain,ytrain)

ypred=regressor.predict(xtest)

from sklearn.metrics import r2_score
print(r2_score(ytest,ypred))
# Out:
# 0.9899058809398598

# %%
for i in x.columns:
    plt.title(i)
    x[i].hist()
    plt.show()

# %%
import scipy.stats as stats

def diagnostic_plots(df, variable):
    # function to plot a histogram and a Q-Q plot
    # side by side, for a certain variable
    
    plt.figure(figsize=(15,6))
    plt.subplot(1, 2, 1)
    plt.title(variable)
    df[variable].hist()

    plt.subplot(1, 2, 2)
    stats.probplot(df[variable], dist="norm", plot=plt)

    plt.show()

# %%
for i in df.columns:
    diagnostic_plots(df,i)
